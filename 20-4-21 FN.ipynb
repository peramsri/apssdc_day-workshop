# %% [markdown]
# ### linear regression with single variable

# %% [markdown]
# ###  +ve Linear relation
#  -input and output have increased viseversa

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
head_df=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Regression/headbrain.csv")
head_df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
head_df.columns
# Out:
# Index(['Gender', 'Age Range', 'Head Size(cm^3)', 'Brain Weight(grams)'], dtype='object')

# %%
head_df.Gender.unique()
# Out:
# array([1, 2], dtype=int64)

# %%
head_df['Gender'].value_counts()
# Out:
# 1    134
# 2    103
# Name: Gender, dtype: int64

# %%
##Data preprocessing
head_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               237 non-null    int64
#  1   Age Range            237 non-null    int64
#  2   Head Size(cm^3)      237 non-null    int64
#  3   Brain Weight(grams)  237 non-null    int64
# dtypes: int64(4)
# memory usage: 7.5 KB

# %%
head_df.describe()
# Out:
#            Gender   Age Range  Head Size(cm^3)  Brain Weight(grams)
# count  237.000000  237.000000       237.000000           237.000000
# mean     1.434599    1.535865      3633.991561          1282.873418
# std      0.496753    0.499768       365.261422           120.340446
# min      1.000000    1.000000      2720.000000           955.000000
# 25%      1.000000    1.000000      3389.000000          1207.000000
# 50%      1.000000    2.000000      3614.000000          1280.000000
# 75%      2.000000    2.000000      3876.000000          1350.000000
# max      2.000000    2.000000      4747.000000          1635.000000

# %%
head_df.isnull().sum()
# Out:
# Gender                 0
# Age Range              0
# Head Size(cm^3)        0
# Brain Weight(grams)    0
# dtype: int64

# %%
input_data=head_df.drop('Brain Weight(grams)',axis=1)
output_data=head_df['Brain Weight(grams)']

# %%
input_data.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)
# 0       1          1             4512
# 1       1          1             3738
# 2       1          1             4261
# 3       1          1             3777
# 4       1          1             4177

# %%
from sklearn.linear_model import LinearRegression 
linear=LinearRegression()

# %%
linear.fit(input_data,output_data)
# Out:
# LinearRegression()

# %%
pred=linear.predict(input_data)
pred
# Out:
# array([1519.93452386, 1330.91463003, 1458.63737483, 1340.43888825,
#        1438.1235879 , 1293.55023241, 1342.39258224, 1287.20072693,
#        1300.38816139, 1390.50229682, 1258.87216403, 1393.18862606,
#        1306.98187861, 1445.69415212, 1353.87053445, 1364.61585141,
#        1272.05959849, 1264.48903426, 1173.88647533, 1498.44388994,
#        1365.10427491, 1406.13184876, 1347.03260547, 1324.07670105,
#        1577.32428491, 1498.19967819, 1403.68973127, 1400.27076679,
#        1261.55849328, 1437.6351644 , 1342.88100574, 1345.07891148,
#        1420.05191847, 1434.21619992, 1433.48356467, 1349.47472296,
#        1279.38595096, 1333.35674752, 1232.25308338, 1270.83853974,
#        1385.61806184, 1274.01329248, 1471.82480928, 1347.03260547,
#        1361.44109867, 1403.20130777, 1470.11532704, 1190.98129777,
#        1307.22609036, 1307.95872561, 1368.27902765, 1344.34627623,
#        1460.83528057, 1410.2834485 , 1397.82864929, 1262.53534027,
#        1368.0348159 , 1411.46881323, 1355.05589918, 1290.09557391,
#        1338.20528849, 1222.69313114, 1478.87125599, 1432.7152354 ,
#        1304.25985536, 1207.0635792 , 1228.06578963, 1217.56468441,
#        1475.940715  , 1463.97433929, 1372.88335686, 1336.25159449,
#        1400.47928452, 1384.84973257, 1327.94839502, 1222.93734289,
#        1262.98806975, 1215.12256692, 1353.83484043, 1330.63472426,
#        1329.41366552, 1335.763171  , 1187.52663927, 1267.62809299,
#        1354.56747568, 1334.2979005 , 1202.17934422, 1225.86788388,
#        1250.2890588 , 1348.2179702 , 1410.00354273, 1204.37724996,
#        1288.38609166, 1346.26427621, 1297.66613813, 1316.95886631,
#        1242.23007108, 1246.38167081, 1286.43239767, 1243.45112982,
#        1247.60272956, 1330.39051251, 1340.64740598, 1288.14187991,
#        1277.6407747 , 1284.96712717, 1378.74443884, 1224.15840164,
#        1350.41587594, 1475.940715  , 1296.44507938, 1254.68487028,
#        1266.16282249, 1271.77969272, 1220.25101365, 1248.57957655,
#        1270.55863398, 1346.50848796, 1398.76980227, 1355.54432268,
#        1224.15840164, 1419.7720127 , 1490.10499645, 1276.6639277 ,
#        1383.38446208, 1317.69150156, 1222.20470765, 1157.00017063,
#        1383.87288558, 1268.84915173, 1289.36293866, 1256.63856428,
#        1382.16340333, 1289.60715041, 1093.22082534, 1234.61942809,
#        1321.31459904, 1201.89505371, 1153.54112738, 1169.90331457,
#        1267.83222597, 1257.57533251, 1170.88016157, 1235.10785159,
#        1348.66631494, 1347.68946794, 1226.07201687, 1193.34764249,
#        1238.28260433, 1150.12216289, 1229.00255786, 1207.02350044,
#        1294.20709488, 1235.35206334, 1336.45572748, 1166.24013833,
#        1196.27818348, 1300.80081211, 1373.8201251 , 1193.83606599,
#        1145.48213966, 1318.38405805, 1261.971144  , 1199.45293622,
#        1249.51634479, 1148.1684689 , 1188.70761925, 1215.57091166,
#        1324.24514003, 1266.36695548, 1163.55380909, 1250.98161528,
#        1267.58801423, 1304.95241184, 1278.33333119, 1177.71809054,
#        1276.86806069, 1265.14589673, 1367.22640787, 1258.30796776,
#        1296.40500062, 1166.72856183, 1373.57591335, 1172.34543206,
#        1245.12053331, 1284.92704841, 1282.48493092, 1121.02527073,
#        1200.3940892 , 1275.85551968, 1144.46959864, 1190.62561923,
#        1104.17466004, 1271.94813169, 1239.95639256, 1048.73859298,
#        1118.33894149, 1188.18350174, 1224.57105236, 1176.70554953,
#        1192.09088972, 1159.85493884, 1171.82131455, 1311.99885855,
#        1120.53684723, 1273.16919044, 1202.34778319, 1347.16535043,
#        1181.83399626, 1035.79537028, 1088.78931984, 1245.81747454,
#        1089.27774334, 1101.48833079, 1247.28274503, 1142.2716929 ,
#        1164.25075032, 1145.69065739, 1169.6234088 , 1199.17303045,
#        1197.21933646, 1070.96186215, 1284.8913544 , 1221.15208787,
#        1262.17966173, 1279.03027242, 1173.53079679, 1398.205606  ,
#        1283.67029565, 1157.41282135, 1271.45970819, 1276.09973143,
#        1156.43597435, 1200.3940892 , 1161.07599758, 1190.13719573,
#        1199.66145395])

# %%
linear.score(input_data,output_data)
# Out:
# 0.6528346387526655

# %%
head_df['Head Size(cm^3)'].value_counts()
# Out:
# 3394    3
# 3399    2
# 3899    2
# 3165    2
# 3804    2
#        ..
# 3402    1
# 3401    1
# 4424    1
# 4423    1
# 3585    1
# Name: Head Size(cm^3), Length: 221, dtype: int64

# %%
linear.predict([[1,1,5000]])
# Out:
# array([1639.10985744])

# %%
linear.coef_
# Out:
# array([-22.5432537 , -23.96844543,   0.24421175])

# %%
linear.intercept_
# Out:
# 464.5628108859039

# %% [markdown]
# ## y-mx+c
# ## c=y-mx

# %% [markdown]
# #### linear regression with applestore.csv

# %%
apple_df=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Regression/AppleStore.csv")
apple_df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# 7192                                              Kubik   126644224      USD
# 7193                                  VR Roller-Coaster   120760320      USD
# 7194              Bret Michaels Emojis + Lyric Keyboard   111322112      USD
# 7195          VR Roller Coaster World - Virtual Reality    97235968      USD
# 7196                       Escape the Sweet Shop Series    90898432      USD
#
#       price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0      3.99             21292                26          4.0              4.5
# 1      0.00            161065                26          4.0              3.5
# 2      0.00            188583              2822          3.5              4.5
# 3      0.00            262241               649          4.0              4.5
# 4      0.00            985920              5320          4.5              5.0
# ...     ...               ...               ...          ...              ...
# 7192   0.00               142                75          4.5              4.5
# 7193   0.00                30                30          4.5              4.5
# 7194   1.99                15                 0          4.5              0.0
# 7195   0.00                85                32          4.5              4.5
# 7196   0.00                 3                 3          5.0              5.0
#
#          ver cont_rating   prime_genre  sup_devices.num  ipadSc_urls.num  \
# 0      6.3.5          4+         Games               38                5
# 1      8.2.2          4+  Productivity               37                5
# 2      5.0.0          4+       Weather               37                5
# 3     5.10.0         12+      Shopping               37                5
# 4      7.5.1          4+     Reference               37                5
# ...      ...         ...           ...              ...              ...
# 7192     1.3          4+         Games               38                5
# 7193     0.9          4+         Games               38                0
# 7194   1.0.2          9+     Utilities               37                1
# 7195  1.0.15         12+         Games               38                0
# 7196     1.0          4+         Games               40                0
#
#       lang.num  vpp_lic
# 0           10        1
# 1           23        1
# 2            3        1
# 3            9        1
# 4           45        1
# ...        ...      ...
# 7192         1        1
# 7193         1        1
# 7194         1        1
# 7195         2        1
# 7196         2        1
#
# [7197 rows x 17 columns]

# %%
apple_df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')

# %%
apple_df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# 7192                                              Kubik   126644224      USD
# 7193                                  VR Roller-Coaster   120760320      USD
# 7194              Bret Michaels Emojis + Lyric Keyboard   111322112      USD
# 7195          VR Roller Coaster World - Virtual Reality    97235968      USD
# 7196                       Escape the Sweet Shop Series    90898432      USD
#
#       price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0      3.99             21292                26          4.0              4.5
# 1      0.00            161065                26          4.0              3.5
# 2      0.00            188583              2822          3.5              4.5
# 3      0.00            262241               649          4.0              4.5
# 4      0.00            985920              5320          4.5              5.0
# ...     ...               ...               ...          ...              ...
# 7192   0.00               142                75          4.5              4.5
# 7193   0.00                30                30          4.5              4.5
# 7194   1.99                15                 0          4.5              0.0
# 7195   0.00                85                32          4.5              4.5
# 7196   0.00                 3                 3          5.0              5.0
#
#          ver cont_rating   prime_genre  sup_devices.num  ipadSc_urls.num  \
# 0      6.3.5          4+         Games               38                5
# 1      8.2.2          4+  Productivity               37                5
# 2      5.0.0          4+       Weather               37                5
# 3     5.10.0         12+      Shopping               37                5
# 4      7.5.1          4+     Reference               37                5
# ...      ...         ...           ...              ...              ...
# 7192     1.3          4+         Games               38                5
# 7193     0.9          4+         Games               38                0
# 7194   1.0.2          9+     Utilities               37                1
# 7195  1.0.15         12+         Games               38                0
# 7196     1.0          4+         Games               40                0
#
#       lang.num  vpp_lic
# 0           10        1
# 1           23        1
# 2            3        1
# 3            9        1
# 4           45        1
# ...        ...      ...
# 7192         1        1
# 7193         1        1
# 7194         1        1
# 7195         2        1
# 7196         2        1
#
# [7197 rows x 17 columns]>

# %%
from sklearn.preprocessing import LabelEncoder
lbr=LabelEncoder()

# %%
apple_df['currency']=lbr.fit_transform(apple_df['currency'])
apple_df['ver']=lbr.fit_transform(apple_df['ver'])
apple_df['cont_rating']=lbr.fit_transform(apple_df['cont_rating'])
apple_df['ver']=lbr.fit_transform(apple_df['ver'])
apple_df['prime_genre']=lbr.fit_transform(apple_df['prime_genre'])

# %%
apple_df.drop(['Unnamed: 0','track_name'],axis=1,inplace=True)

# %%
apple_df.columns
# Out:
# Index(['id', 'size_bytes', 'currency', 'price', 'rating_count_tot',
#        'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver',
#        'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num',
#        'lang.num', 'vpp_lic'],
#       dtype='object')

# %%
x = apple_df.drop('price',axis=1)
y=apple_df['price']

# %%
sns.pairplot(apple_df)

# %%
from sklearn.linear_model import LinearRegression 
lr=LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.score(x,y)*100
# Out:
# 5.93489219270531

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# ## polynomial regression with single variable
# #####            y = ax^2+bx+c

# %%
marks=pd.read_csv("marks.csv")
marks
# Out:
#    education  marks
# 0         10     67
# 1         34     67
# 2         56     78
# 3         89     67
# 4         67     87
# 5         78     67
# 6         56     96
# 7         45     67

# %%
marks.isnull().sum()
# Out:
# education    0
# marks        0
# dtype: int64

# %%
plt.scatter(marks['education'],marks['marks'])
plt.show()

# %%
x=marks[['education']]
y=marks['marks']

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures()
linear=LinearRegression()

# %%
x_poly=poly.fit_transform(x)

# %%
linear.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
y_predict=linear.predict(x_poly)

# %%
y_predict
# Out:
# array([62.38617779, 75.82585027, 79.27763977, 68.55091975, 77.82265367,
#        74.24708033, 79.27763977, 78.61203864])

# %%
linear.score(x_poly,y)*100
# Out:
# 28.241081615475537

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
 r2_score(y,y_predict)
# Out:
# 0.2824108161547554

# %%
mean_absolute_error(y,y_predict)
# Out:
# 7.628382190805729

# %%
mean_squared_error(y,y_predict)
# Out:
# 81.80516695835789

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()

# %%
print (boston)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
#        15.6, 11.8, 13.8, 15.6, 14.6, 17.8, 15.4, 21.5, 19.6, 15.3, 19.4,
#        17. , 15.6, 13.1, 41.3, 24.3, 23.3, 27. , 50. , 50. , 50. , 22.7,
#        25. , 50. , 23.8, 23.8, 22.3, 17.4, 19.1, 23.1, 23.6, 22.6, 29.4,
#        23.2, 24.6, 29.9, 37.2, 39.8, 36.2, 37.9, 32.5, 26.4, 29.6, 50. ,
#        32. , 29.8, 34.9, 37. , 30.5, 36.4, 31.1, 29.1, 50. , 33.3, 30.3,
#        34.6, 34.9, 32.9, 24.1, 42.3, 48.5, 50. , 22.6, 24.4, 22.5, 24.4,
#        20. , 21.7, 19.3, 22.4, 28.1, 23.7, 25. , 23.3, 28.7, 21.5, 23. ,
#        26.7, 21.7, 27.5, 30.1, 44.8, 50. , 37.6, 31.6, 46.7, 31.5, 24.3,
#        31.7, 41.7, 48.3, 29. , 24. , 25.1, 31.5, 23.7, 23.3, 22. , 20.1,
#        22.2, 23.7, 17.6, 18.5, 24.3, 20.5, 24.5, 26.2, 24.4, 24.8, 29.6,
#        42.8, 21.9, 20.9, 44. , 50. , 36. , 30.1, 33.8, 43.1, 48.8, 31. ,
#        36.5, 22.8, 30.7, 50. , 43.5, 20.7, 21.1, 25.2, 24.4, 35.2, 32.4,
#        32. , 33.2, 33.1, 29.1, 35.1, 45.4, 35.4, 46. , 50. , 32.2, 22. ,
#        20.1, 23.2, 22.3, 24.8, 28.5, 37.3, 27.9, 23.9, 21.7, 28.6, 27.1,
#        20.3, 22.5, 29. , 24.8, 22. , 26.4, 33.1, 36.1, 28.4, 33.4, 28.2,
#        22.8, 20.3, 16.1, 22.1, 19.4, 21.6, 23.8, 16.2, 17.8, 19.8, 23.1,
#        21. , 23.8, 23.1, 20.4, 18.5, 25. , 24.6, 23. , 22.2, 19.3, 22.6,
#        19.8, 17.1, 19.4, 22.2, 20.7, 21.1, 19.5, 18.5, 20.6, 19. , 18.7,
#        32.7, 16.5, 23.9, 31.2, 17.5, 17.2, 23.1, 24.5, 26.6, 22.9, 24.1,
#        18.6, 30.1, 18.2, 20.6, 17.8, 21.7, 22.7, 22.6, 25. , 19.9, 20.8,
#        16.8, 21.9, 27.5, 21.9, 23.1, 50. , 50. , 50. , 50. , 50. , 13.8,
#        13.8, 15. , 13.9, 13.3, 13.1, 10.2, 10.4, 10.9, 11.3, 12.3,  8.8,
#         7.2, 10.5,  7.4, 10.2, 11.5, 15.1, 23.2,  9.7, 13.8, 12.7, 13.1,
#        12.5,  8.5,  5. ,  6.3,  5.6,  7.2, 12.1,  8.3,  8.5,  5. , 11.9,
#        27.9, 17.2, 27.5, 15. , 17.2, 17.9, 16.3,  7. ,  7.2,  7.5, 10.4,
#         8.8,  8.4, 16.7, 14.2, 20.8, 13.4, 11.7,  8.3, 10.2, 10.9, 11. ,
#         9.5, 14.5, 14.1, 16.1, 14.3, 11.7, 13.4,  9.6,  8.7,  8.4, 12.8,
#        10.5, 17.1, 18.4, 15.4, 10.8, 11.8, 14.9, 12.6, 14.1, 13. , 13.4,
#        15.2, 16.1, 17.8, 14.9, 14.1, 12.7, 13.5, 14.9, 20. , 16.4, 17.7,
#        19.5, 20.2, 21.4, 19.9, 19. , 19.1, 19.1, 20.1, 19.9, 19.6, 23.2,
#        29.8, 13.8, 13.3, 16.7, 12. , 14.6, 21.4, 23. , 23.7, 25. , 21.8,
#        20.6, 21.2, 19.1, 20.6, 15.2,  7. ,  8.1, 13.6, 20.1, 21.8, 24.5,
#        23.1, 19.7, 18.3, 21.2, 17.5, 16.8, 22.4, 20.6, 23.9, 22. , 11.9]), 'feature_names': array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7'), 'DESCR': ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,000\n        - PTRATIO  pupil-teacher ratio by town\n        - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town\n        - LSTAT    % lower status of the population\n        - MEDV     Median value of owner-occupied homes in $1000's\n\n    :Missing Attribute Values: None\n\n    :Creator: Harrison, D. and Rubinfeld, D.L.\n\nThis is a copy of UCI ML housing dataset.\nhttps://archive.ics.uci.edu/ml/machine-learning-databases/housing/\n\n\nThis dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.\n\nThe Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic\nprices and the demand for clean air', J. Environ. Economics & Management,\nvol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics\n...', Wiley, 1980.   N.B. Various transformations are used in the table on\npages 244-261 of the latter.\n\nThe Boston house-price data has been used in many machine learning papers that address regression\nproblems.   \n     \n.. topic:: References\n\n   - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.\n   - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.\n", 'filename': 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\sklearn\\datasets\\data\\boston_house_prices.csv'}

# %%
x=boston.data
x
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
y=boston.target
y
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
#        15.6, 11.8, 13.8, 15.6, 14.6, 17.8, 15.4, 21.5, 19.6, 15.3, 19.4,
#        17. , 15.6, 13.1, 41.3, 24.3, 23.3, 27. , 50. , 50. , 50. , 22.7,
#        25. , 50. , 23.8, 23.8, 22.3, 17.4, 19.1, 23.1, 23.6, 22.6, 29.4,
#        23.2, 24.6, 29.9, 37.2, 39.8, 36.2, 37.9, 32.5, 26.4, 29.6, 50. ,
#        32. , 29.8, 34.9, 37. , 30.5, 36.4, 31.1, 29.1, 50. , 33.3, 30.3,
#        34.6, 34.9, 32.9, 24.1, 42.3, 48.5, 50. , 22.6, 24.4, 22.5, 24.4,
#        20. , 21.7, 19.3, 22.4, 28.1, 23.7, 25. , 23.3, 28.7, 21.5, 23. ,
#        26.7, 21.7, 27.5, 30.1, 44.8, 50. , 37.6, 31.6, 46.7, 31.5, 24.3,
#        31.7, 41.7, 48.3, 29. , 24. , 25.1, 31.5, 23.7, 23.3, 22. , 20.1,
#        22.2, 23.7, 17.6, 18.5, 24.3, 20.5, 24.5, 26.2, 24.4, 24.8, 29.6,
#        42.8, 21.9, 20.9, 44. , 50. , 36. , 30.1, 33.8, 43.1, 48.8, 31. ,
#        36.5, 22.8, 30.7, 50. , 43.5, 20.7, 21.1, 25.2, 24.4, 35.2, 32.4,
#        32. , 33.2, 33.1, 29.1, 35.1, 45.4, 35.4, 46. , 50. , 32.2, 22. ,
#        20.1, 23.2, 22.3, 24.8, 28.5, 37.3, 27.9, 23.9, 21.7, 28.6, 27.1,
#        20.3, 22.5, 29. , 24.8, 22. , 26.4, 33.1, 36.1, 28.4, 33.4, 28.2,
#        22.8, 20.3, 16.1, 22.1, 19.4, 21.6, 23.8, 16.2, 17.8, 19.8, 23.1,
#        21. , 23.8, 23.1, 20.4, 18.5, 25. , 24.6, 23. , 22.2, 19.3, 22.6,
#        19.8, 17.1, 19.4, 22.2, 20.7, 21.1, 19.5, 18.5, 20.6, 19. , 18.7,
#        32.7, 16.5, 23.9, 31.2, 17.5, 17.2, 23.1, 24.5, 26.6, 22.9, 24.1,
#        18.6, 30.1, 18.2, 20.6, 17.8, 21.7, 22.7, 22.6, 25. , 19.9, 20.8,
#        16.8, 21.9, 27.5, 21.9, 23.1, 50. , 50. , 50. , 50. , 50. , 13.8,
#        13.8, 15. , 13.9, 13.3, 13.1, 10.2, 10.4, 10.9, 11.3, 12.3,  8.8,
#         7.2, 10.5,  7.4, 10.2, 11.5, 15.1, 23.2,  9.7, 13.8, 12.7, 13.1,
#        12.5,  8.5,  5. ,  6.3,  5.6,  7.2, 12.1,  8.3,  8.5,  5. , 11.9,
#        27.9, 17.2, 27.5, 15. , 17.2, 17.9, 16.3,  7. ,  7.2,  7.5, 10.4,
#         8.8,  8.4, 16.7, 14.2, 20.8, 13.4, 11.7,  8.3, 10.2, 10.9, 11. ,
#         9.5, 14.5, 14.1, 16.1, 14.3, 11.7, 13.4,  9.6,  8.7,  8.4, 12.8,
#        10.5, 17.1, 18.4, 15.4, 10.8, 11.8, 14.9, 12.6, 14.1, 13. , 13.4,
#        15.2, 16.1, 17.8, 14.9, 14.1, 12.7, 13.5, 14.9, 20. , 16.4, 17.7,
#        19.5, 20.2, 21.4, 19.9, 19. , 19.1, 19.1, 20.1, 19.9, 19.6, 23.2,
#        29.8, 13.8, 13.3, 16.7, 12. , 14.6, 21.4, 23. , 23.7, 25. , 21.8,
#        20.6, 21.2, 19.1, 20.6, 15.2,  7. ,  8.1, 13.6, 20.1, 21.8, 24.5,
#        23.1, 19.7, 18.3, 21.2, 17.5, 16.8, 22.4, 20.6, 23.9, 22. , 11.9])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing  import PolynomialFeatures
linear=LinearRegression()
poly=PolynomialFeatures()

# %%
x_poly=poly.fit_transform(x)

# %%
x_poly
# Out:
# array([[1.00000000e+00, 6.32000000e-03, 1.80000000e+01, ...,
#         1.57529610e+05, 1.97656200e+03, 2.48004000e+01],
#        [1.00000000e+00, 2.73100000e-02, 0.00000000e+00, ...,
#         1.57529610e+05, 3.62766600e+03, 8.35396000e+01],
#        [1.00000000e+00, 2.72900000e-02, 0.00000000e+00, ...,
#         1.54315409e+05, 1.58310490e+03, 1.62409000e+01],
#        ...,
#        [1.00000000e+00, 6.07600000e-02, 0.00000000e+00, ...,
#         1.57529610e+05, 2.23851600e+03, 3.18096000e+01],
#        [1.00000000e+00, 1.09590000e-01, 0.00000000e+00, ...,
#         1.54802902e+05, 2.54955600e+03, 4.19904000e+01],
#        [1.00000000e+00, 4.74100000e-02, 0.00000000e+00, ...,
#         1.57529610e+05, 3.12757200e+03, 6.20944000e+01]])

# %%
linear.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
y_predict=linear.predict(x_poly)

# %%
y_predict
# Out:
# array([24.3257606 , 21.70742285, 31.45342135, 31.95919538, 32.07212031,
#        26.10454512, 21.34575117, 17.67411315, 16.36192608, 20.29943573,
#        19.91724825, 20.23052788, 23.96145451, 19.65293026, 18.22623086,
#        19.4250592 , 21.39045048, 17.2018621 , 13.16257799, 18.3190372 ,
#        14.36456084, 16.82459021, 15.94069529, 14.01989698, 15.32403767,
#        14.68252087, 15.67004573, 15.66516936, 17.70622563, 19.69532382,
#        14.74991584, 16.45054364, 15.57771444, 15.09033239, 14.98173881,
#        23.21955752, 22.11419535, 22.75332499, 24.08637547, 29.08266878,
#        35.22468638, 30.75417054, 23.24988306, 25.04442406, 21.98865497,
#        19.21104228, 21.16608906, 18.83638859, 18.62922585, 18.79638457,
#        21.20877659, 21.15733445, 27.28492296, 21.86870527, 17.99705374,
#        31.36499536, 25.11179447, 29.67087817, 20.04769182, 18.55793023,
#        17.67108107, 18.21862924, 22.70828819, 24.45363855, 31.12562895,
#        26.25592554, 19.23983514, 18.90538359, 16.7105186 , 18.38422012,
#        24.10908473, 19.02738845, 20.83308148, 21.92169595, 25.87996757,
#        21.61203372, 18.46890187, 20.82891095, 19.03578365, 19.66530609,
#        28.60627615, 25.25531864, 24.60785949, 22.68042266, 25.43930471,
#        27.64641881, 23.44745851, 24.82671738, 27.75052226, 31.15607083,
#        25.66422701, 24.96460748, 24.96832538, 23.08138883, 21.89752889,
#        27.87832475, 22.78410244, 37.74576473, 42.46404696, 33.75161886,
#        24.73222589, 26.95298016, 18.50219524, 20.07413602, 21.42955792,
#        19.0138967 , 18.2498908 , 21.84768176, 21.07618618, 19.05184114,
#        24.33367991, 23.18478203, 15.66327274, 14.43021166, 21.6892004 ,
#        17.17437327, 21.06666946, 19.89061022, 19.0232116 , 19.61249804,
#        21.37493849, 21.95514536, 19.94832516, 16.13240373, 19.34129882,
#        22.57306433, 15.03471744, 15.21356094, 18.30715597, 16.67033386,
#        20.71394742, 23.25723982, 22.40050972, 17.31686795, 14.01278961,
#        17.70758414, 16.28971028, 19.12458277, 12.87028432, 16.15864301,
#        12.97355866, 13.55524611, 14.22475052, 16.2563436 , 14.0750258 ,
#        17.07266057, 14.84233034, 15.29460728, 16.83519495, 18.12121737,
#        22.70421565, 16.93632579, 15.26824427, 18.12649381, 15.15985012,
#        11.96396112, 10.73563445, 36.91972196, 27.15617251, 29.373402  ,
#        33.10782361, 46.64361429, 46.95085847, 47.68576562, 23.03366649,
#        24.17519605, 48.23309994, 19.95142877, 25.55085516, 26.67144287,
#        19.76273012, 22.08660173, 20.41158736, 27.06209528, 24.71383965,
#        32.95117784, 25.77534568, 27.21711135, 31.43428302, 36.36657   ,
#        39.2832092 , 28.58189571, 36.21813655, 31.1132766 , 22.54123139,
#        26.13751268, 44.11401474, 32.33627605, 30.62806261, 34.58638012,
#        30.7116493 , 27.76049554, 33.68923724, 31.54266381, 27.25505257,
#        47.56488109, 36.0587219 , 29.75765538, 33.54480636, 34.0269438 ,
#        34.63082731, 22.49336576, 43.08964717, 46.7290498 , 49.51403344,
#        21.84310186, 23.6048708 , 17.65652037, 22.68621278, 17.36121428,
#        18.20830023, 17.99516773, 22.92948818, 25.13515329, 25.05833864,
#        23.32192898, 23.74959517, 27.25631523, 17.5037936 , 24.25142097,
#        27.41356981, 19.29483366, 28.23140359, 28.58611917, 44.68690658,
#        47.09540212, 42.28018332, 33.49434543, 43.59845591, 31.09897947,
#        22.69528413, 35.16982555, 44.86955655, 43.58470845, 29.19505107,
#        23.91931808, 27.77875268, 34.48901951, 25.2301594 , 25.61174059,
#        26.15843737, 19.4281863 , 21.54495192, 24.3687824 , 17.02230656,
#        17.26321673, 22.0457623 , 19.98976994, 21.91788423, 26.97698724,
#        24.95066726, 23.82648897, 29.50577772, 45.9468019 , 21.72804308,
#        20.39220607, 38.95795059, 53.09162962, 34.80519378, 31.11586571,
#        34.94080186, 38.09669006, 47.32551062, 33.34820914, 34.38817561,
#        23.41861963, 30.98207283, 51.61887085, 46.96924436, 22.53771186,
#        20.69364619, 24.51906466, 26.31725192, 34.01610029, 34.95809329,
#        32.83661675, 33.83372176, 34.29611921, 27.05802798, 35.30617976,
#        43.53638506, 34.43920636, 43.75400198, 54.14505088, 33.17517793,
#        22.62433887, 19.81799388, 20.94592583, 21.74951231, 22.56543064,
#        31.99840891, 36.00292397, 28.57359409, 23.97408056, 21.43124056,
#        30.80487359, 27.56446302, 19.83337343, 23.86166811, 32.40464664,
#        26.95734143, 24.9141233 , 25.48572743, 32.34023631, 33.6663878 ,
#        29.25226438, 37.95881069, 32.52105665, 26.23160005, 19.64684856,
#        13.93474841, 24.44755983, 18.35386431, 21.72905588, 22.09450197,
#        17.12121499, 16.35084152, 17.48395109, 22.62146926, 21.21919823,
#        25.24075389, 24.88710916, 22.38794196, 18.8707763 , 25.85401678,
#        26.64517498, 25.06900024, 22.63557231, 19.81528497, 24.1809932 ,
#        19.45720816, 16.92831743, 17.81286716, 23.85345829, 23.86703777,
#        21.9909333 , 20.57037246, 20.45403981, 22.08475924, 21.50789058,
#        21.14143288, 30.2987566 , 13.97850358, 24.61992121, 29.35371375,
#        17.99846232, 17.15757382, 24.62725401, 26.24731493, 25.70315289,
#        21.68253458, 23.57774794, 21.80228126, 31.57527101, 19.13213837,
#        21.65057087, 22.56567633, 17.18830013, 24.33329093, 18.90431607,
#        23.88177848, 17.79661644, 22.30000782, 19.84753156, 25.62990248,
#        29.78609002, 22.90455246, 25.38382316, 41.7444123 , 48.52334785,
#        51.00177765, 31.31007552, 45.64220023, 10.72991002, 13.70763206,
#        19.77899516, 12.32554615, 13.00068903,  9.61015224, 11.37970328,
#        13.00667059, 11.59687674, 11.62670052, 11.51448429, 12.29984224,
#         7.66461205,  7.88454473,  8.93939161,  9.55046606, 14.13711286,
#        16.78720045, 16.24801564, 10.97438622, 18.39161038, 15.41166627,
#        15.86930335, 14.88655448, 14.92419159,  4.26717496, 11.40584493,
#         5.42285454, 11.37481904, 13.01572382,  9.2542752 ,  8.58668101,
#         1.42166197, 15.64869142, 25.28452706, 16.24160898, 20.62224412,
#        17.41147029, 18.5083487 , 14.32678807, 16.6581136 , 10.83084202,
#         8.54273355,  9.41535985,  9.93243289,  6.10158575,  9.12861156,
#        17.11824787, 18.39223468, 22.35457063, 11.27149141, 11.32053351,
#         9.96924281, 10.29578733,  9.08122754, 12.24590087, 11.80702519,
#        18.86050427, 18.25366437, 22.3028847 , 16.72075844, 15.73707676,
#         9.84602118, 11.5669452 ,  7.20965016,  5.64472568, 10.18322265,
#         6.49524629, 10.57891762, 14.78109372, 10.7437768 , 10.03872073,
#         8.96323061, 14.98969293, 13.10791183, 12.51854575, 14.09534943,
#        14.39224648, 14.8232311 , 15.7133466 , 13.57501292, 12.68430638,
#        13.93179429, 12.10132897,  9.88074553, 16.26952755, 17.22401965,
#        17.66275156, 18.68260038, 18.02890468, 21.80459082, 20.38372993,
#        19.70402157, 14.33396411, 16.61923707, 15.37542415, 18.96091187,
#        19.07828677, 23.54413962, 22.0110141 , 26.12214792, 19.4953438 ,
#        14.71749949, 17.09245038, 12.87344992, 17.11162388, 21.99037349,
#        23.47375238, 28.45178258, 29.69535303, 20.64278686, 20.04289365,
#        22.59884715, 18.44930398, 22.96523964, 14.69084179,  9.35375679,
#         7.28745794, 12.96924508, 21.55999911, 21.81315446, 24.02305245,
#        24.55973208, 16.63030648, 18.84653413, 21.44571769, 18.24318898,
#        18.82971871, 19.25741613, 16.2058686 , 22.34383297, 20.50602388,
#        15.73920739])

# %%
linear.score(x_poly,y)*100
# Out:
# 92.39966561767861

# %%
fuel_df=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Regression/FuelConsumptionCo2.csv")
fuel_df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0             AS5        Z                   9.9                  6.7
# 1              M6        Z                  11.2                  7.7
# 2             AV7        Z                   6.0                  5.8
# 3             AS6        Z                  12.7                  9.1
# 4             AS6        Z                  12.1                  8.7
# ...           ...      ...                   ...                  ...
# 1062          AS6        X                  13.4                  9.8
# 1063          AS6        X                  13.2                  9.5
# 1064          AS6        X                  13.4                  9.8
# 1065          AS6        X                  12.9                  9.3
# 1066          AS6        X                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                      8.5                        33           196
# 1                      9.6                        29           221
# 2                      5.9                        48           136
# 3                     11.1                        25           255
# 4                     10.6                        27           244
# ...                    ...                       ...           ...
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294
#
# [1067 rows x 13 columns]

# %%
fuel_df.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
fuel_df.info
# Out:
# <bound method DataFrame.info of       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0             AS5        Z                   9.9                  6.7
# 1              M6        Z                  11.2                  7.7
# 2             AV7        Z                   6.0                  5.8
# 3             AS6        Z                  12.7                  9.1
# 4             AS6        Z                  12.1                  8.7
# ...           ...      ...                   ...                  ...
# 1062          AS6        X                  13.4                  9.8
# 1063          AS6        X                  13.2                  9.5
# 1064          AS6        X                  13.4                  9.8
# 1065          AS6        X                  12.9                  9.3
# 1066          AS6        X                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                      8.5                        33           196
# 1                      9.6                        29           221
# 2                      5.9                        48           136
# 3                     11.1                        25           255
# 4                     10.6                        27           244
# ...                    ...                       ...           ...
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294
#
# [1067 rows x 13 columns]>

# %%
from sklearn.preprocessing import LabelEncoder
fuel_df["MAKE"]=lbr.fit_transform(fuel_df["MAKE"])
fuel_df["MODEL"]=lbr.fit_transform(fuel_df["MODEL"])
fuel_df["VEHICLECLASS"]=lbr.fit_transform(fuel_df["VEHICLECLASS"])
fuel_df["TRANSMISSION"]=lbr.fit_transform(fuel_df["TRANSMISSION"])
fuel_df["FUELTYPE"]=lbr.fit_transform(fuel_df["FUELTYPE"])

# %%
X=fuel_df.drop("CO2EMISSIONS",axis=1)
y=fuel_df["CO2EMISSIONS"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2a70883f99dc> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)
#
# NameError: name 'x' is not defined
